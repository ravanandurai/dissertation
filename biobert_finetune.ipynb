# %%
# Install required libraries
# %pip install transformers datasets scikit-learn pandas torch --quiet

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainer, Seq2SeqTrainingArguments, DataCollatorForSeq2Seq
from sklearn.model_selection import train_test_split
import torch

# %%
# Upload your expanded_noisy_training_data.csv file before running this cell
df = pd.read_excel("/content/sample_data/icd10_noisy_descriptions_long.xlsx").dropna()
df = df[["noisy_text", "clean_text"]]
# Shuffle the DataFrame
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
#get random 15000 records
df = df.sample(n=15000, random_state=42).reset_index(drop=True)
df.head()
# Out:
#                                           noisy_text  \
# 0  Type 1 diabetes mellitus with unspecified diab...
# 1  Atherosclerotic heart disease of native corona...
# 2  Toxic effect of othek peticndes, intentional s...
# 3              Malignant neoplasm offleft upper limb
# 4  yiffuse traumatic brain injury with loss of co...
#
#                                           clean_text
# 0  Type 1 diabetes mellitus with unspecified diab...
# 1  Atherosclerotic heart disease of native corona...
# 2  Toxic effect of other pesticides, intentional ...
# 3              Malignant neoplasm of left upper limb
# 4  Diffuse traumatic brain injury with loss of co...

# %%
# Split into training and validation sets
train_df, val_df = train_test_split(df, test_size=0.1, random_state=42)
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)

# %%
from transformers import EncoderDecoderModel, BertTokenizerFast, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import Dataset
import torch
# Define the maximum input and target lengths
# Load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
model = EncoderDecoderModel.from_encoder_decoder_pretrained("emilyalsentzer/Bio_ClinicalBERT", "emilyalsentzer/Bio_ClinicalBERT")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.txt: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of BertLMHeadModel were not initialized from the model checkpoint at emilyalsentzer/Bio_ClinicalBERT and are newly initialized: ['bert.encoder.layer.0.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.0.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.0.crossattention.output.dense.bias', 'bert.encoder.layer.0.crossattention.output.dense.weight', 'bert.encoder.layer.0.crossattention.self.key.bias', 'bert.encoder.layer.0.crossattention.self.key.weight', 'bert.encoder.layer.0.crossattention.self.query.bias', 'bert.encoder.layer.0.crossattention.self.query.weight', 'bert.encoder.layer.0.crossattention.self.value.bias', 'bert.encoder.layer.0.crossattention.self.value.weight', 'bert.encoder.layer.1.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.1.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.1.crossattention.output.dense.bias', 'bert.encoder.layer.1.crossattention.output.dense.weight', 'bert.encoder.layer.1.crossattention.self.key.bias', 'bert.encoder.layer.1.crossattention.self.key.weight', 'bert.encoder.layer.1.crossattention.self.query.bias', 'bert.encoder.layer.1.crossattention.self.query.weight', 'bert.encoder.layer.1.crossattention.self.value.bias', 'bert.encoder.layer.1.crossattention.self.value.weight', 'bert.encoder.layer.10.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.10.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.10.crossattention.output.dense.bias', 'bert.encoder.layer.10.crossattention.output.dense.weight', 'bert.encoder.layer.10.crossattention.self.key.bias', 'bert.encoder.layer.10.crossattention.self.key.weight', 'bert.encoder.layer.10.crossattention.self.query.bias', 'bert.encoder.layer.10.crossattention.self.query.weight', 'bert.encoder.layer.10.crossattention.self.value.bias', 'bert.encoder.layer.10.crossattention.self.value.weight', 'bert.encoder.layer.11.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.11.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.11.crossattention.output.dense.bias', 'bert.encoder.layer.11.crossattention.output.dense.weight', 'bert.encoder.layer.11.crossattention.self.key.bias', 'bert.encoder.layer.11.crossattention.self.key.weight', 'bert.encoder.layer.11.crossattention.self.query.bias', 'bert.encoder.layer.11.crossattention.self.query.weight', 'bert.encoder.layer.11.crossattention.self.value.bias', 'bert.encoder.layer.11.crossattention.self.value.weight', 'bert.encoder.layer.2.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.2.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.2.crossattention.output.dense.bias', 'bert.encoder.layer.2.crossattention.output.dense.weight', 'bert.encoder.layer.2.crossattention.self.key.bias', 'bert.encoder.layer.2.crossattention.self.key.weight', 'bert.encoder.layer.2.crossattention.self.query.bias', 'bert.encoder.layer.2.crossattention.self.query.weight', 'bert.encoder.layer.2.crossattention.self.value.bias', 'bert.encoder.layer.2.crossattention.self.value.weight', 'bert.encoder.layer.3.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.3.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.3.crossattention.output.dense.bias', 'bert.encoder.layer.3.crossattention.output.dense.weight', 'bert.encoder.layer.3.crossattention.self.key.bias', 'bert.encoder.layer.3.crossattention.self.key.weight', 'bert.encoder.layer.3.crossattention.self.query.bias', 'bert.encoder.layer.3.crossattention.self.query.weight', 'bert.encoder.layer.3.crossattention.self.value.bias', 'bert.encoder.layer.3.crossattention.self.value.weight', 'bert.encoder.layer.4.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.4.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.4.crossattention.output.dense.bias', 'bert.encoder.layer.4.crossattention.output.dense.weight', 'bert.encoder.layer.4.crossattention.self.key.bias', 'bert.encoder.layer.4.crossattention.self.key.weight', 'bert.encoder.layer.4.crossattention.self.query.bias', 'be ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Tokenization
def tokenize_function(example):
    input_encodings = tokenizer(example["noisy_text"], padding="max_length", truncation=True, max_length=64)
    target_encodings = tokenizer(example["clean_text"], padding="max_length", truncation=True, max_length=64)
    input_encodings["labels"] = target_encodings["input_ids"]
    return input_encodings

# %%
from sklearn.model_selection import train_test_split

train_df, eval_df = train_test_split(df, test_size=0.1, random_state=42)

train_dataset = Dataset.from_pandas(train_df)
eval_dataset = Dataset.from_pandas(eval_df)

tokenized_train = train_dataset.map(tokenize_function, batched=False)
tokenized_eval = eval_dataset.map(tokenize_function, batched=False)
# Out:
# Map:   0%|          | 0/13500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    padding="longest",  # or "max_length"
    return_tensors="pt"

)

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

training_args = Seq2SeqTrainingArguments(
    output_dir="./model_output_final",
    eval_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=2,
    num_train_epochs=10,
    predict_with_generate=True,
    logging_dir="./logs",
    logging_steps=100,
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    report_to="none"   # disable wandb / tensorboard / comet
)

# %%
# Set decoder_start_token_id and pad_token_id
model.config.decoder_start_token_id = tokenizer.cls_token_id
model.config.pad_token_id = tokenizer.pad_token_id


# Trainer

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_eval,
    tokenizer=tokenizer,
    data_collator=data_collator
)



trainer.train()
# Save the model and tokenizer
model.save_pretrained("./clinicalbert_noisy_text_correction_large_3")
tokenizer.save_pretrained("./clinicalbert_noisy_text_correction_large_3")
# Out:
# /tmp/ipython-input-491609052.py:8: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='8440' max='8440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8440/8440 1:22:09, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.118200</td>
#       <td>0.087797</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.053300</td>
#       <td>0.060136</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.032100</td>
#       <td>0.064538</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.021400</td>
#       <td>0.081845</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.016700</td>
#       <td>0.117432</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.012500</td>
#       <td>0.093527</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.010600</td>
#       <td>0.142622</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.009300</td>
#       <td>0.171575</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.008200</td>
#       <td>0.201133</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.006700</td>
#       <td>0.182581</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:577: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# There were missing keys in the checkpoint model loaded: ['decoder.cls.predictions.decoder.weight', 'decoder.cls.predictions.decoder.bias'].
# ('./clinicalbert_noisy_text_correction_large_3/tokenizer_config.json',
#  './clinicalbert_noisy_text_correction_large_3/special_tokens_map.json',
#  './clinicalbert_noisy_text_correction_large_3/vocab.txt',
#  './clinicalbert_noisy_text_correction_large_3/added_tokens.json',
#  './clinicalbert_noisy_text_correction_large_3/tokenizer.json')

# %%
import pandas as pd
import torch
import re
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from sklearn.metrics import f1_score, recall_score, accuracy_score, confusion_matrix

def normalize(text):
    # Lowercase, remove spaces around punctuation, collapse multiple spaces
    text = text.lower()
    text = re.sub(r'\s*([-,])\s*', r'\1', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def evaluate_seq2seq_model(eval_df, model_path, noisy_col="noisy_text", clean_col="clean_text", sample_size=200, batch_size=64):
    # Shuffle and randomly select samples for evaluation
    eval_df = eval_df.sample(frac=1, random_state=42).reset_index(drop=True)
    texts = [normalize(t) for t in eval_df[noisy_col].tolist()]
    true_labels = [normalize(t) for t in eval_df[clean_col].tolist()]
    sample_indices = pd.Series(texts).sample(n=sample_size, random_state=42).index
    texts = [texts[i] for i in sample_indices]
    true_labels = [true_labels[i] for i in sample_indices]

    # Load the saved seq2seq model and tokenizer
    model = AutoModelForSeq2SeqLM.from_pretrained(model_path)
    tokenizer = AutoTokenizer.from_pretrained(model_path)

    # Move model to GPU if available
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = model.to(device)

    # Batch prediction
    decoded_preds = []
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt")
        inputs = {k: v.to(device) for k, v in inputs.items()}
        with torch.no_grad():
            outputs = model.generate(
                input_ids=inputs["input_ids"],
                attention_mask=inputs["attention_mask"],
                decoder_start_token_id=model.config.decoder_start_token_id,
                pad_token_id=model.config.pad_token_id,
                max_length=128,
                num_beams=1
            )
        decoded_preds.extend([normalize(tokenizer.decode(output, skip_special_tokens=True)) for output in outputs])

    # Word match metrics
    y_true = []
    y_pred = []
    for true_text, pred_text in zip(true_labels, decoded_preds):
        true_words = set(true_text.split())
        pred_words = set(pred_text.split())
        match = int(true_words.issubset(pred_words))
        y_true.append(1)
        y_pred.append(match)

    # Calculate metrics
    f1 = f1_score(y_true, y_pred, average='binary')
    recall = recall_score(y_true, y_pred, average='binary')
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)

    print("F1 Score:", f1)
    print("Recall:", recall)
    print("Accuracy:", accuracy)
    print("Confusion Matrix:\n", cm)

    for i in range(len(true_labels)):
        print(f"True: {true_labels[i]}\nPredicted: {decoded_preds[i]}\nMatch: {y_pred[i]}")

# Example usage:
evaluate_seq2seq_model(eval_df, "./clinicalbert_noisy_text_correction_large_3")
# Out:
# F1 Score: 0.7341772151898734
# Recall: 0.58
# Accuracy: 0.58
# Confusion Matrix:
#  [[  0   0]
#  [ 84 116]]
# True: depression,unspecified
# Predicted:
# Match: 0
# True: congenital malformations of corpus callosum
# Predicted: congenital malformations of corpus callosum
# Match: 1
# True: unstable burst fracture of unspecified lumbar vertebra,initial encounter for closed fracture
# Predicted: unstable burst fracture of unspecified lumbar vertebra,initial encounter for closed fracture
# Match: 1
# True: other specified diabetes mellitus with unspecified diabetic retinopathy without macular edema
# Predicted: other specified diabetes mellitus with unspecified diabetic retinopathy without macular edema
# Match: 1
# True: malignant neoplasm of peripheral nerves of right lower limb,including hip
# Predicted:
# Match: 0
# True: burkitt lymphoma,lymph nodes of multiple sites
# Predicted:
# Match: 0
# True: toxic effect of chlorine gas,intentional self-harm,sequela
# Predicted: toxic effect of chlorine gas,intentional self-harm,sequela
# Match: 1
# True: fracture of humerus following insertion of orthopedic implant,joint prosthesis,or bone plate,right arm
# Predicted: fracture of humerus following insertion of orthopedic implant,joint prosthesis,or bone plate
# Match: 0
# True: intentional self-harm by hot household appliances,sequela
# Predicted: intentional self-harm by hot household appliances,sequela
# Match: 1
# True: congenital malformation of spinal cord,unspecified
# Predicted: congenital malformation of spinal cord,unspecified
# Match: 1
# True: gonococcal pneumonia
# Predicted: gonococcal pneumonia
# Match: 1
# True: type 1 diabetes mellitus with moderate nonproliferative diabetic retinopathy with macular edema,unspecified eye
# Predicted: type 1 diabetes mellitus with moderate nonproliferative diabetic retinopathy with macular edema,unspecified eye
# Match: 1
# True: atherosclerotic heart disease of native coronary artery with unspecified angina pectoris
# Predicted: atherosclerosis of native coronary artery of transplanted heart with unspecified angina pectoris
# Match: 0
# True: inhalant dependence with intoxication,uncomplicated
# Predicted: inhalant dependence with intoxication,uncomplicated
# Match: 1
# True: chronic postrheumatic arthropathy [jaccoud],right shoulder
# Predicted: chronic postrheumatic arthropathy [ jaccoud ],right shoulder
# Match: 0
# True: pneumococcal arthritis,right ankle and foot
# Predicted: pneumococcal arthritis,right ankle and foot
# Match: 1
# True: cerebral infarction due to unspecified occlusion or stenosis of left anterior cerebral artery
# Predicted: cerebral infarction due to unspecified occlusion or stenosis of right anterior cerebral artery
# Match: 0
# True: toxic effect of contact with stingray,intentional self-harm,sequela
# Predicted: toxic effect of contact with venomous mangun,intentional self-harm,sequela
# Match: 0
# True: sedative,hypnotic or anxiolytic abuse with withdrawal delirium
# Predicted: sedative,hypnotic or anxiolytic abuse with withdrawal delirium
# Match: 1
# True: fracture of neck,unspecified,initial encounter
# Predicted: fracture of neck,unspecified,initial encounter
# Match: 1
# True: type 1 diabetes mellitus with diabetic peripheral angiopathy with gangrene
# Predicted: type 1 diabetes mellitus with diabetic peripheral angiopathy with gangrene
# Match: 1
# True: systemic sclerosis with myopathy
# Predicted: systemic sclerosis with myopathy
# Match: 1
# True: pneumocystosis
# Predicted: pneumococcal pneumonia
# Match: 0
# True: unspecified juvenile rheumatoid arthritis,unspecified hand
# Predicted: unspecified juvenile rheumatoid arthritis,unspecified hand
# Match: 1
# True: felty's syndrome,multiple sites
# Predicted: felty's syndrome,multiple sites
# Match: 1
# True: sjogren syndrome with peripheral nervous system involvement
# Predicted: sjogren syndrome with peripheral nervous system involvement
# Match: 1
# True: malignant neoplasm of overlapping sites of hypopharynx
# Predicted:
# Match: 0
# True: kidney transplant failure
# Predicted:
# Match: 0
# True: pressure ulcer of left lower back,stage 3
# Predicted: pressure ulcer of left lower back,stage 3
# Match: 1
# True: malignant neoplasm of left retina
# Predicted:
# Match: 0
# True: neonatal cerebral infarction,bilateral
# Predicted: neonatal cerebral infarction,bilateral
# Match: 1
# True: malignant neoplasm of other parts of pancreas
# Predicted:
# Match: 0
# True: rheumatoid polyneuropathy with rheumatoid arthritis of left wrist
# Predicted: rheumatoid polyneuropathy with rheumatoid arthritis of left wrist
# Match: 1
# True: displaced fracture of base of neck of unspecified femur,initial encounter for open fracture type i or ii
# Predicted:
# Match: 0
# True: glaucoma with increased episcleral venous pressure,right eye
# Predicted: glaucoma with increased episcleral venous pressure,right eye
# Match: 1
# True: nondisplaced avulsion fracture of right ilium,initial encounter for open fracture
# Predicted: nondisplaced avulsion fracture of right ilium,initial encounter for open fracture
# Match: 1
# True: poisoning by unspecified antidepressants,intentional self-harm,initial encounter
# Predicted: poisoning by unspecified antidepressants,intentional self-harm,initial encounter
# Match: 1
# True: other benign neuroendocrine tumors
# Predicted: other benign nephropathy
# Match: 0
# True: displaced fracture of medial condyle of left femur,initial encounter for open fracture type i or ii
# Predicted:
# Match: 0
# True: other osteoporosis with current pathological fracture,left shoulder,initial encounter for fracture
# Predicted: other osteoporosis with current pathological fracture,left shoulder,initial encounter for fracture
# Match: 1
# True: pathological fracture,left hand,initial encounter for fracture
# Predicted: pathological fracture,left hand,initial encounter for fracture
# Match: 1
# True: wedge compression fracture of fourth thoracic vertebra,initial encounter for closed fracture
# Predicted:
# Match: 0
# True: type 2 diabetes mellitus with proliferative diabetic retinopathy with traction retinal detachment involving the macula,left eye
# Predicted: type 2 diabetes mellitus with proliferative diabetic retinopathy with traction retinal detachment involving the macula,left eye
# Match: 1
# True: atherosclerosis of native arteries of right leg with ulceration of other part of foot
# Predicted: atherosclerosis of native arteries of right leg with ulceration of other part of foot
# Match: 1
# True: other specified diabetes mellitus with ketoacidosis without coma
# Predicted: other specified diabetes mellitus with ketoacidosis without coma
# Match: 1
# True: inhalant abuse with inhalant-induced psychotic disorder with hallucinations
# Predicted: inhalant abuse with inhalant-induced psychotic disorder with hallucinations
# Match: 1
# True: partial traumatic amputation at left hip joint,subsequent encounter
# Predicted: partial traumatic amputation at left hip joint,subsequent encounter
# Match: 1
# True: juvenile arthritis,unspecified,right hip
# Predicted: juvenile arthritis,unspecified,right hip
# Match: 1
# True: secondary malignant neoplasm of left adrenal gland
# Predicted: secondary malignant neoplasm of left adrenal gland
# Match: 1
# True: chronic postrheumatic arthropathy [jaccoud],right hip
# Predicted: chronic postrheumatic arthropathy [ jaccoud ],right hip
# Match: 0
# True: factitious disorder imposed on self,with predominantly psychological signs and symptoms
# Predicted: factitious disorder imposed on self,with predominantly physical signs and symptoms
# Match: 0
# True: pressure ulcer of left elbow,unstageable
# Predicted: pressure ulcer of left elbow,unstageable
# Match: 1
# True: rheumatoid myopathy with rheumatoid arthritis of unspecified elbow
# Predicted: rheumatoid myopathy with rheumatoid arthritis of unspecified wrist
# Match: 0
# True: primary open-angle glaucoma,unspecified eye,severe stage
# Predicted: primary open-angle glaucoma,unspecified eye,severe stage
# Match: 1
# True: displaced intertrochanteric fracture of right femur,initial encounter for open fracture type i or ii
# Predicted:
# Match: 0
# True: inhalant dependence with intoxication delirium
# Predicted: inhalant dependence with inhalant-induced delirium
# Match: 0
# True: capsular glaucoma with pseudoexfoliation of lens,unspecified eye,severe stage
# Predicted: capsular glaucoma with pseudoexfoliation of lens,unspecified eye,sequela
# Match: 0
# True: pressure ulcer of right heel,stage 4
# Predicted: pressure ulcer of right heel,stage 4
# Match: 1
# True: other secondary osteonecrosis,left tibia
# Predicted: other secondary osteonecrosis,left tibia
# Match: 1
# True: other specified disorders involving the immune mechanism,not elsewhere classified
# Predicted: other specified disorders of the immune system,not elsewhere classified
# Match: 0
# True: non-pressure chronic ulcer of unspecified calf with bone involvement without evidence of necrosis
# Predicted: non-pressure chronic ulcer of unspecified calf with bone involvement without evidence of necrosis
# Match: 1
# True: unspecified fracture of left femur,initial encounter for open fracture type i or ii
# Predicted: unspecified fracture of left femur,initial encounter for open fracture type i or ii
# Match: 1
# True: nontraumatic intracerebral hemorrhage,multiple localized
# Predicted: nontraumatic intracerebral hemorrhage,multiple sites
# Match: 0
# True: diabetes mellitus due to underlying condition with mild nonproliferative diabetic retinopathy without macular edema,right eye
# Predicted: diabetes mellitus due to underlying condition with mild nonproliferative diabetic retinopathy without macular edema,right eye
# Match: 1
# True: type 1 diabetes mellitus with severe nonproliferative diabetic retinopathy with macular edema,right eye
# Predicted: type 1 diabetes mellitus with severe nonproliferative diabetic retinopathy with macular edema,right eye
# Match: 1
# True: coma scale,best verbal response,incomprehensible words,unspecified time
# Predicted: coma scale,best verbal response,none,unspecified time
# Match: 0
# True: glaucoma secondary to eye trauma,left eye,moderate stage
# Predicted: glaucoma secondary to eye trauma,left eye,moderate stage
# Match: 1
# True: corticobasal degeneration
# Predicted: coagulation factor deficiency
# Match: 0
# True: neuroma of amputation stump,right lower extremity
# Predicted: necrosis of amputation stump,right lower extremity
# Match: 0
# True: pathological fracture in neoplastic disease,right fibula,initial encounter for fracture
# Predicted: pathological fracture in neoplastic disease,right fibula,initial encounter for fracture
# Match: 1
# True: malignant carcinoid tumor of the ileum
# Predicted:
# Match: 0
# True: malignant neoplasm of lateral floor of mouth
# Predicted:
# Match: 0
# True: instability of internal right knee prosthesis,initial encounter
# Predicted:
# Match: 0
# True: other genetic related intellectual disability
# Predicted: other genetic related intellectual disability
# Match: 1
# True: hallucinogen abuse with intoxication,unspecified
# Predicted: hallucinogen abuse with intoxication,unspecified
# Match: 1
# True: crohn's disease of small intestine without complications
# Predicted:
# Match: 0
# True: displacement of vascular dialysis catheter,subsequent encounter
# Predicted: displacement of vascular dialysis catheter,subsequent encounter
# Match: 1
# True: budd-chiari syndrome
# Predicted: budd-chiari syndrome
# Match: 1
# True: other monocytic leukemia,not having achieved remission
# Predicted: other monocytic leukemia not having achieved remission
# Match: 0
# True: hemiplegia and hemiparesis following other nontraumatic intracranial hemorrhage affecting unspecified side
# Predicted: hemiplegia and hemiparesis following other nontraumatic intracranial hemorrhage affecting unspecified side
# Match: 1
# True: common variable immunodeficiency with predominant abnormalities of b-cell numbers and function
# Predicted: common variable immunodeficiency with predominantly antibody defects of b-cell numbers and function
# Match: 0
# True: cicatricial pemphigoid
# Predicted: cyclothic liver disease
# Match: 0
# True: rheumatoid heart disease with rheumatoid arthritis of left ankle and foot
# Predicted: rheumatoid heart disease with rheumatoid arthritis of left ankle and foot
# Match: 1
# True: other mast cell activation disorder
# Predicted: other mast cell activation
# Match: 0
# True: adult t-cell lymphoma/leukemia (htlv-1-associated),in remission
# Predicted:
# Match: 0
# True: peripheral t-cell lymphoma,not elsewhere classified,lymph nodes of axilla and upper limb
# Predicted: peripheral t-cell lymphoma,not elsewhere classified,lymph nodes of axilla and upper limb
# Match: 1
# True: breakdown (mechanical) of implanted electronic neurostimulator,generator,initial encounter
# Predicted: breakdown ( mechanical ) of implanted electronic neurostimulator,generator,initial encounter
# Match: 0
# True: atherosclerosis of unspecified type of bypass graft(s) of the extremities with gangrene,right leg
# Predicted: atherosclerosis of unspecified type of bypass graft ( s ) of the extremities with gangrene,right leg
# Match: 0
# True: malignant neoplasm of right kidney,except renal pelvis
# Predicted:
# Match: 0
# True: injury of left internal carotid artery,intracranial portion,not elsewhere classified with loss of consciousness status unknown,sequela
# Predicted: injury of left internal carotid artery,intracranial portion,not elsewhere classified with loss of consciousness status unknown,sequela
# Match: 1
# True: unspecified injury at c7 level of cervical spinal cord,initial encounter
# Predicted: unspecified injury at c7 level of cervical spinal cord,initial encounter
# Match: 1
# True: other infective spondylopathies,lumbosacral region
# Predicted: other infective spondylopathies,lumbosacral region
# Match: 1
# True: other mechanical complication of internal fixation device of right femur,initial encounter
# Predicted: other mechanical complication of internal fixation device of right femur,initial encounter
# Match: 1
# True: anemia due to other disorders of glutathione metabolism
# Predicted: anemia due to disorders of glycogen metabolism
# Match: 0
# True: nondisplaced dome fracture of unspecified acetabulum,initial encounter for open fracture
# Predicted: nondisplaced dome fracture of unspecified acetabulum,initial encounter for open fracture
# Match: 1
# True: nondisplaced comminuted fracture of shaft of right femur,initial encounter for open fracture type i or ii
# Predicted: nondisplaced comminuted fracture of shaft of right femur,initial encounter for open fracture type i or ii
# Match: 1
# True: anaplastic large cell lymphoma,alk-negative,intrapelvic lymph nodes
# Predicted: anaplastic large cell lymphoma,alk-positive,intrapelvic lymph nodes
# Match: 0
# True: drug or chemical induced diabetes mellitus with proliferative diabetic retinopathy without macular edema,unspecified eye
# Predicted: or chemical induced diabetes mellitus with proliferative diabetic retinopathy without macular edema,unspecified eye
# Match: 0
# True: acute embolism and thrombosis of unspecified deep veins of left proximal lower extremity
# Predicted: acute embolism and thrombosis of unspecified deep veins of left lower extremity
# Match: 0
# True: other paralytic syndrome following other nontraumatic intracranial hemorrhage,bilateral
# Predicted: other paralytic syndrome following other nontraumatic intracranial hemorrhage,bilateral
# Match: 1
# True: unspecified dementia with behavioral disturbance
# Predicted: unspecified dementia with behavioral disturbance
# Match: 1
# True: kaposi's sarcoma of skin
# Predicted: kaposi's sarcoma of skin
# Match: 1
# True: multifocal fibrosclerosis
# Predicted: multifocal osteomyelitis
# Match: 0
# True: postdysenteric arthropathy,left shoulder
# Predicted:
# Match: 0
# True: idiopathic mast cell activation syndrome
# Predicted:
# Match: 0
# True: fracture of neck,unspecified,initial encounter
# Predicted: fracture of skull,unspecified,initial encounter
# Match: 0
# True: displaced fracture of medial wall of left acetabulum,initial encounter for open fracture
# Predicted:
# Match: 0
# True: intentional self-harm by steam or hot vapors,sequela
# Predicted: intentional self-harm by steam or hot vapors,sequela
# Match: 1
# True: anomalous pulmonary venous connection,unspecified
# Predicted: anomalous pulmonary vein,unspecified
# Match: 0
# True: localization-related (focal) (partial) idiopathic epilepsy and epileptic syndromes with seizures of localized onset,not intractable,without status epilepticus
# Predicted: localization-related ( focal ) ( partial ) idiopathic epilepsy and epileptic syndromes with seizures of localized onset,not intractable,without status epilepticus
# Match: 0
# True: chronic postrheumatic arthropathy [jaccoud],other specified site
# Predicted: chronic postrheumatic arthropathy [ jaccoud ],unspecified site
# Match: 0
# True: other osteoporosis with current pathological fracture,left ankle and foot,initial encounter for fracture
# Predicted: other osteoporosis with current pathological fracture,left ankle and foot,initial encounter for fracture
# Match: 1
# True: drug or chemical induced diabetes mellitus with severe nonproliferative diabetic retinopathy with macular edema,bilateral
# Predicted: or chemical induced diabetes mellitus with severe nonproliferative diabetic retinopathy with macular edema,bilateral
# Match: 0
# True: sezary disease,spleen
# Predicted: sezary disease,spleen
# Match: 1
# True: rheumatoid bursitis,left elbow
# Predicted: rheumatoid bursitis,left elbow
# Match: 1
# True: complete lesion at c7 level of cervical spinal cord,sequela
# Predicted: complete lesion at c7 level of cervical spinal cord,sequela
# Match: 1
# True: burns involving 80-89% of body surface with 70-79% third degree burns
# Predicted: burns involving 80-89 % of body surface with 60-69 % third degree burns
# Match: 0
# True: fracture of angle of left mandible,sequela
# Predicted: fracture of angle of left mandible,sequela
# Match: 1
# True: complete traumatic metacarpophalangeal amputation of left middle finger,sequela
# Predicted: complete traumatic metacarpophalangeal amputation of left ring finger,sequela
# Match: 0
# True: complete lesion at c1 level of cervical spinal cord,sequela
# Predicted: complete lesion at c1 level of cervical spinal cord,sequela
# Match: 1
# True: unspecified fracture of unspecified femur,initial encounter for closed fracture
# Predicted: unspecified fracture of unspecified femur,initial encounter for closed fracture
# Match: 1
# True: type iii traumatic spondylolisthesis of sixth cervical vertebra,initial encounter for open fracture
# Predicted: type iii traumatic spondylolisthesis of sixth cervical vertebra,initial encounter for open fracture
# Match: 1
# True: nondisplaced subtrochanteric fracture of unspecified femur,initial encounter for open fracture type iiia,iiib,or iiic
# Predicted: nondisplaced subtrochanteric fracture of unspecified femur,initial encounter for open fracture type iiia,iiib,or iiic
# Match: 1
# True: pressure ulcer of right elbow,stage 2
# Predicted: pressure ulcer of right elbow,stage 2
# Match: 1
# True: rheumatoid polyneuropathy with rheumatoid arthritis of left hip
# Predicted: rheumatoid polyneuropathy with rheumatoid arthritis of left hip
# Match: 1
# True: dissection of vertebral artery
# Predicted: dissection of vertebral artery
# Match: 1
# True: juvenile arthritis,unspecified,left wrist
# Predicted: juvenile arthritis,unspecified,left wrist
# Match: 1
# True: other chronic viral hepatitis
# Predicted: other chronic viral hepatitis
# Match: 1
# True: corticobasal degeneration
# Predicted: cortical degeneration
# Match: 0
# True: intentional self-harm by other larger firearm discharge,sequela
# Predicted: intentional self-harm by other larger firearm discharge,sequela
# Match: 1
# True: rheumatoid myopathy with rheumatoid arthritis of right hip
# Predicted: rheumatoid myopathy with rheumatoid arthritis of right hip
# Match: 1
# True: familial hypophosphatemia
# Predicted: familial hypochondriasis
# Match: 0
# True: incomplete lesion of l2 level of lumbar spinal cord,sequela
# Predicted: incomplete lesion of l2 level of lumbar spinal cord,sequela
# Match: 1
# True: other hyperlipidemia
# Predicted: other hyperlipidemia
# Match: 1
# True: poisoning by other fibrinolysis-affecting drugs,intentional self-harm,sequela
# Predicted: poisoning poisoning by other mycotoxin-inhibitors,intentional self-harm,sequela
# Match: 0
# True: alcoholic polyneuropathy
# Predicted: alcoholic polyneuropathy
# Match: 1
# True: other monocytic leukemia,not having achieved remission
# Predicted: other monocytic leukemia not having achieved remission
# Match: 0
# True: dermatopolymyositis,unspecified with respiratory involvement
# Predicted: dermatopolymyositis with respiratory involvement
# Match: 0
# True: diabetes mellitus due to underlying condition with mild nonproliferative diabetic retinopathy without macular edema,left eye
# Predicted: diabetes mellitus due to underlying condition with mild nonproliferative diabetic retinopathy without macular edema,left eye
# Match: 1
# True: drug-induced thyroiditis
# Predicted: drug drug drug drug drug-induced thyroiditis
# Match: 1
# True: type iii occipital condyle fracture,left side,initial encounter for open fracture
# Predicted: type iii occipital condyle fracture,left side,initial encounter for open fracture
# Match: 1
# True: nondisplaced fracture of epiphysis (separation) (upper) of right femur,initial encounter for open fracture type iiia,iiib,or iiic
# Predicted: nondisplaced fracture of epiphysis ( separation ) ( upper ) of right femur,initial encounter for open fracture type iiia,iiib,or iiic
# Match: 0
# True: malignant neoplasm of cecum
# Predicted:
# Match: 0
# True: sedative,hypnotic or anxiolytic abuse with sedative,hypnotic or anxiolytic-induced psychotic disorder,unspecified
# Predicted: sedative,hypnotic or anxiolytic abuse with sedative,hypnotic or anxiolytic-induced disorder
# Match: 0
# True: occlusion and stenosis of unspecified carotid artery
# Predicted: occlusion and stenosis of unspecified carotid artery
# Match: 1
# True: pathological fracture in other disease,left ulna,initial encounter for fracture
# Predicted: pathological fracture in other disease,left ulna,initial encounter for fracture
# Match: 1
# True: atherosclerosis of unspecified type of bypass graft(s) of the extremities with intermittent claudication,left leg
# Predicted: atherosclerosis of unspecified type of bypass graft ( s ) of the extremities with intermittent claudication,left leg
# Match: 0
# True: unspecified injury at unspecified level of thoracic spinal cord,initial encounter
# Predicted: unspecified injury at unspecified level of thoracic spinal cord,initial encounter
# Match: 1
# True: infection and inflammatory reaction due to other urinary stents,initial encounter
# Predicted: infection and inflammatory reaction due to other urinary stent,initial encounter
# Match: 0
# True: malignant neoplasm of upper-inner quadrant of unspecified male breast
# Predicted:
# Match: 0
# True: chronic embolism and thrombosis of unspecified iliac vein
# Predicted: chronic embolism and thrombosis of unspecified iliac vein
# Match: 1
# True: other fracture of first thoracic vertebra,initial encounter for open fracture
# Predicted: other fracture of first thoracic vertebra,initial encounter for open fracture
# Match: 1
# True: fracture of medial orbital wall,left side,sequela
# Predicted: fracture of medial orbital wall,left side,sequela
# Match: 1
# True: secondary malignant neoplasm of unspecified adrenal gland
# Predicted: secondary malignant neoplasm of unspecified adrenal gland
# Match: 1
# True: follicular lymphoma grade i,intrathoracic lymph nodes
# Predicted: follicular lymphoma grade iiib,intrathoracic lymph nodes
# Match: 0
# True: malignant neoplasm of ribs,sternum and clavicle
# Predicted:
# Match: 0
# True: nondisplaced segmental fracture of shaft of right femur,initial encounter for closed fracture
# Predicted: nondisplaced segmental fracture of shaft of right femur,initial encounter for closed fracture
# Match: 1
# True: dehiscence of amputation stump
# Predicted:
# Match: 0
# True: pneumococcal arthritis,unspecified ankle and foot
# Predicted: pneumococcal arthritis,unspecified ankle and foot
# Match: 1
# True: secondary malignant neoplasm of unspecified ovary
# Predicted: secondary malignant neoplasm of unspecified ovary
# Match: 1
# True: partial traumatic amputation at level between knee and ankle,unspecified lower leg,subsequent encounter
# Predicted: partial traumatic amputation at level between knee and ankle,unspecified lower leg,subsequent encounter
# Match: 1
# True: diabetes mellitus due to underlying condition with diabetic nephropathy
# Predicted: diabetes mellitus due to underlying condition with diabetic nephropathy
# Match: 1
# True: acute hematogenous osteomyelitis,left shoulder
# Predicted: acute hematogenous osteomyelitis,left shoulder
# Match: 1
# True: traumatic hemorrhage of cerebrum,unspecified,with loss of consciousness of 1 hours to 5 hours 59 minutes,sequela
# Predicted: traumatic hemorrhage of cerebrum,unspecified,with loss of consciousness of 1 hour to 5 hours 59 minutes,sequela
# Match: 1
# True: contusion,laceration,and hemorrhage of cerebellum with loss of consciousness of 30 minutes or less,initial encounter
# Predicted: contusion,laceration,and hemorrhage of cerebellum with loss of consciousness of 30 minutes or less,initial encounter
# Match: 1
# True: pigmentary glaucoma,left eye,severe stage
# Predicted: pigmentary glaucoma,left eye,severe stage
# Match: 1
# True: partial traumatic amputation of two or more unspecified lesser toes,initial encounter
# Predicted: partial traumatic amputation of two or more unspecified lesser toes,initial encounter
# Match: 1
# True: felty's syndrome,left knee
# Predicted: felty's syndrome,left knee
# Match: 1
# True: chronic multifocal osteomyelitis,left femur
# Predicted: chronic multifocal osteomyelitis,left femur
# Match: 1
# True: rheumatoid bursitis,unspecified hip
# Predicted: rheumatoid nodule,unspecified hip
# Match: 0
# True: unspecified displaced fracture of sixth cervical vertebra,initial encounter for closed fracture
# Predicted: unspecified displaced fracture of sixth cervical vertebra,initial encounter for closed fracture
# Match: 1
# True: aneurysm of the ascending aorta,without rupture
# Predicted:
# Match: 0
# True: acute hematogenous osteomyelitis,unspecified shoulder
# Predicted: acute hematogenous osteomyelitis,unspecified shoulder
# Match: 1
# True: stable burst fracture of first thoracic vertebra,initial encounter for open fracture
# Predicted: stable burst fracture of first thoracic vertebra,initial encounter for open fracture
# Match: 1
# True: other chronic hepatitis,not elsewhere classified
# Predicted: other chronic hepatitis,not elsewhere classified
# Match: 1
# True: nondisplaced fracture of epiphysis (separation) (upper) of right femur,initial encounter for open fracture type iiia,iiib,or iiic
# Predicted: nondisplaced fracture of epiphysis ( separation ) ( upper ) of right femur,initial encounter for open fracture type iiia,iiib,or iiic
# Match: 0
# True: other paralytic syndrome following nontraumatic subarachnoid hemorrhage affecting unspecified side
# Predicted: other paralytic syndrome following nontraumatic subarachnoid hemorrhage affecting unspecified side
# Match: 1
# True: other specified diabetes mellitus with moderate nonproliferative diabetic retinopathy without macular edema,bilateral
# Predicted: other specified diabetes mellitus with moderate nonproliferative diabetic retinopathy without macular edema,bilateral
# Match: 1
# True: other stimulant abuse,uncomplicated
# Predicted: other stimulant dependence,uncomplicated
# Match: 0
# True: chronic postrheumatic arthropathy [jaccoud],right shoulder
# Predicted: chronic postrheumatic arthropathy [ jaccoud ],right shoulder
# Match: 0
# True: atherosclerosis of nonautologous biological bypass graft(s) of the extremities with gangrene,bilateral legs
# Predicted: atherosclerosis of nonautologous biological bypass graft ( s ) of the extremities with gangrene,bilateral legs
# Match: 0
# True: displaced midcervical fracture of left femur,initial encounter for open fracture type iiia,iiib,or iiic
# Predicted:
# Match: 0
# True: merkel cell carcinoma of unspecified part of face
# Predicted: merkel cell carcinoma of unspecified part of face
# Match: 1
# True: traumatic subdural hemorrhage with loss of consciousness of 6 hours to 24 hours,initial encounter
# Predicted: traumatic subdural hemorrhage with loss of consciousness of 6 hours to 24 hours,initial encounter
# Match: 1
# True: pressure ulcer of right heel,stage 4
# Predicted: pressure ulcer of right heel,stage 4
# Match: 1
# True: mycosis fungoides,lymph nodes of inguinal region and lower limb
# Predicted:
# Match: 0
# True: hodgkin lymphoma,unspecified,lymph nodes of axilla and upper limb
# Predicted: hodgkin lymphoma,unspecified,lymph nodes of axilla and upper limb
# Match: 1
# True: nondisplaced fracture of posterior column [ilioischial] of right acetabulum,initial encounter for open fracture
# Predicted: nondisplaced fracture of posterior column [ ilioischial ] of right acetabulum,initial encounter for open fracture
# Match: 0
# True: cerebral infarction due to embolism of unspecified posterior cerebral artery
# Predicted: cerebral infarction due to embolism of unspecified posterior cerebral artery
# Match: 1
# True: toxic effect of venom of tarantula,intentional self-harm,sequela
# Predicted: toxic effect of venom of tarantula,intentional self-harm,sequela
# Match: 1
# True: primary open-angle glaucoma,unspecified eye,indeterminate stage
# Predicted: primary open-angle glaucoma,unspecified eye,indeterminate stage
# Match: 1
# True: other specified diabetes mellitus with hyperosmolarity with coma
# Predicted: other specified diabetes mellitus with hyperosmolarity with coma
# Match: 1
# True: drug or chemical induced diabetes mellitus with mild nonproliferative diabetic retinopathy with macular edema,left eye
# Predicted: or chemical induced diabetes mellitus with mild nonproliferative diabetic retinopathy with macular edema,left eye
# Match: 0
# True: pathological fracture,right ankle,initial encounter for fracture
# Predicted: pathological fracture,right ankle,initial encounter for fracture
# Match: 1
# True: displaced spiral fracture of shaft of unspecified femur,initial encounter for open fracture type i or ii
# Predicted:
# Match: 0
# True: diabetes mellitus due to underlying condition with proliferative diabetic retinopathy with combined traction retinal detachment and rhegmatogenous retinal detachment,left eye
# Predicted: diabetes mellitus due to underlying condition with proliferative diabetic retinopathy with combined traction retinal detachment and rhegmatogenous retinal detachment,left eye
# Match: 1
# True: mediastinal (thymic) large b-cell lymphoma,intra-abdominal lymph nodes
# Predicted:
# Match: 0
# True: infection and inflammatory reaction due to indwelling ureteral stent,initial encounter
# Predicted: infection and inflammatory reaction due to indwelling urethrall stent,initial encounter
# Match: 0
# True: anterior cord syndrome at unspecified level of cervical spinal cord,initial encounter
# Predicted: aneurysm of unspecified cervical spinal cord,initial encounter
# Match: 0
# True: malignant neoplasm of overlapping sites of left male breast
# Predicted:
# Match: 0

# %%
import shutil, os
from pathlib import Path

NOTEBOOK_PATH = "/content/biobert-finetune 1 (2).ipynb"
MODEL_DIR     = "/content/clinicalbert_noisy_text_correction_large_3"
LOG_DIR       = "/content/logs"
STAGING       = "/content/export_to_github"

shutil.rmtree(STAGING, ignore_errors=True)
os.makedirs(STAGING, exist_ok=True)

# Copy model
shutil.copytree(MODEL_DIR, Path(STAGING)/"models"/"clinicalbert_noisy_text_correction_large_3")

# Copy notebook
if os.path.exists(NOTEBOOK_PATH):
    shutil.copy2(NOTEBOOK_PATH, STAGING)

# Copy logs
if os.path.isdir(LOG_DIR):
    shutil.copytree(LOG_DIR, Path(STAGING)/"logs", dirs_exist_ok=True)

print("✅ Staging complete →", STAGING)
